# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

# ---- functions ----
def f1(x): return jnp.sin(10 * x)
def f2(x): return 1.0 / (1.0 + 25.0 * x**2)
def f3(x): return jnp.where((x >= 0.0) & (x <= 2.0), 1.0, 0.0)

# ---- losses ----
def huber_loss(r, delta=1.0):
    return jnp.where(jnp.abs(r) <= delta, 0.5 * r**2, delta * (jnp.abs(r) - 0.5 * delta))

def lp_loss(r, p=1.5):
    return jnp.abs(r)**p

datasets = [
    {'f': f1, 'a': -1, 'b': 1, 'name': 'sin(10x)'},
    {'f': f2, 'a': -5, 'b': 5, 'name': 'Runge function'},
    {'f': f3, 'a': -2, 'b': 2, 'name': 'Heaviside step function'}
]

loss_types = ['huber', 'lp']
m, n = 100, 10

for loss_type in loss_types:
    # create one figure with 3 rows x 1 column
    fig, axes = plt.subplots(3, 1, figsize=(7, 14))

    for row_idx, ds in enumerate(datasets):
        a, b, f, name = ds['a'], ds['b'], ds['f'], ds['name']

        # training data and design
        x = jnp.linspace(a, b, m)
        y = f(x)
        x_norm = 2 * (x - a) / (b - a) - 1
        A = jnp.vander(x_norm, n + 1, increasing=True)

        # initial LS
        try:
            theta = jnp.linalg.lstsq(A, y, rcond=None)[0]
        except AttributeError:
            theta = jnp.linalg.pinv(A) @ y

        # IRLS
        max_iter, tol = 1000, 1e-8
        for _ in range(max_iter):  # don't overwrite row_idx
            r = y - A @ theta
            rho_val = huber_loss(r) if loss_type == 'huber' else lp_loss(r)
            w = rho_val / (r**2 + 1e-8)      # weights
            W = jnp.diag(w)
            try:
                theta_new = jnp.linalg.lstsq(W @ A, W @ y, rcond=None)[0]
            except AttributeError:
                theta_new = jnp.linalg.pinv(W @ A) @ (W @ y)

            if jnp.linalg.norm(theta_new - theta) < tol:
                break
            theta = theta_new

        # prediction
        x_test = jnp.linspace(a, b, 1000)
        x_test_norm = 2 * (x_test - a) / (b - a) - 1
        A_test = jnp.vander(x_test_norm, n + 1, increasing=True)
        y_pred = A_test @ theta

        # plot on this row
        ax = axes[row_idx]
        ax.scatter(x, y, color='red', s=10, label='Data')
        ax.plot(x_test, y_pred, color='blue', label='Fitted')
        ax.set_title(f'{name} with {loss_type} loss, n={n}')
        ax.set_xlabel("x")
        ax.set_ylabel("y")
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.savefig(f'compare_{loss_type}_loss.png', dpi=300)
    plt.close(fig)

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import csv
from dataclasses import dataclass

# Datasets (Gamma functions)
def f1(x):  # sin(10x) on [-1, 1]
    return jnp.sin(10.0 * x)

def f2(x):  # Runge function on [-5, 5]
    return 1.0 / (1.0 + 25.0 * x**2)

def f3(x):  # Step function on [-2, 2]: 1 in [0,2], else 0
    return jnp.where((x >= 0.0) & (x <= 2.0), 1.0, 0.0)

@dataclass
class Dataset:
    f: callable
    a: float
    b: float
    name: str

DATASETS = [
    Dataset(f=f1, a=-1.0, b= 1.0, name="sin(10x)"),
    Dataset(f=f2, a=-5.0, b= 5.0, name="Runge function"),
    Dataset(f=f3, a=-2.0, b= 2.0, name="Heaviside step function"),
]

# Losses
def huber_loss(r, delta=1.0):
    # 0.5 r^2 for |r|<=delta, delta(|r| - 0.5 delta) otherwise
    absr = jnp.abs(r)
    quad = 0.5 * r**2
    lin = delta * (absr - 0.5 * delta)
    return jnp.where(absr <= delta, quad, lin)

def lp_loss(r, p=1.5):
    return jnp.abs(r)**p

# Names for plotting/CSV
LOSS_SPECS = [
    ("huber", lambda r: huber_loss(r, delta=1.0)),
    ("lp",    lambda r: lp_loss(r, p=1.5)),
]

# Utilities
def normalize_to_unit_interval(x, a, b):
    return 2.0 * (x - a) / (b - a) - 1.0

def vandermonde(x_norm, degree):
    return jnp.vander(x_norm, degree + 1, increasing=True)

def initial_theta(A, y):
    try:
        return jnp.linalg.lstsq(A, y, rcond=None)[0]
    except AttributeError:
        return jnp.linalg.pinv(A) @ y

# IRLS core (weights per assignment: w = rho(r) / r^2)
def irls(A, y, rho_fn, max_iter=1000, tol=1e-8, eps=1e-8):
    """
    Solve min sum_i rho(r_i) via IRLS:
      - r = y - A @ theta
      - w_i = rho(r_i) / (r_i^2 + eps)
      - Solve weighted LS: min_theta || diag(sqrt(w)) (y - A theta) ||^2
    """
    theta = initial_theta(A, y)
    for _ in range(max_iter):
        r = y - A @ theta
        rho_val = rho_fn(r)
        w = rho_val / (r**2 + eps)
        # Weighted least squares: minimize || W^(1/2) (y - A theta) ||_2
        # Equivalent normal eq: (A^T W A) theta = A^T W y
        # We'll form W*A and W*y via diag weights:
        sqrtw = jnp.sqrt(w)
        Aw = A * sqrtw[:, None]
        yw = y * sqrtw
        try:
            theta_new = jnp.linalg.lstsq(Aw, yw, rcond=None)[0]
        except AttributeError:
            theta_new = jnp.linalg.pinv(Aw) @ yw

        if jnp.linalg.norm(theta_new - theta) < tol:
            return theta_new
        theta = theta_new
    return theta  # reached max_iter

# Experiment configuration
m = 100
degrees = list(range(1, 31))  # 1..30
num_test = 1000

# Run experiments
results = []  # rows: (dataset, loss, degree, max_error)

for (loss_name, rho_fn) in LOSS_SPECS:
    for ds in DATASETS:
        a, b, f, name = ds.a, ds.b, ds.f, ds.name

        # Training data (equispaced per assignment option)
        x_train = jnp.linspace(a, b, m)
        y_train = f(x_train)

        # Normalize x to [-1,1] for stability; build test grid too
        x_train_norm = normalize_to_unit_interval(x_train, a, b)
        x_test = jnp.linspace(a, b, num_test)
        x_test_norm = normalize_to_unit_interval(x_test, a, b)
        y_test_true = f(x_test)

        # Sweep degrees
        for n in degrees:
            # Design matrices
            A = vandermonde(x_train_norm, n)
            A_test = vandermonde(x_test_norm, n)

            # Initial LS (warm start), then IRLS
            theta0 = initial_theta(A, y_train)
            # IRLS using the assignment's weight rule
            theta = irls(A, y_train, rho_fn=rho_fn, max_iter=1000, tol=1e-8, eps=1e-8)

            # Evaluate required metric
            y_pred = A_test @ theta
            err_max = jnp.max(jnp.abs(y_test_true - y_pred))
            results.append((name, loss_name, int(n), float(err_max)))

            # Console progress
            print(f"{name:26s} | loss={loss_name:5s} | n={n:2d} | max_err={float(err_max):.6e}")


# Save CSV of results
csv_path = "exercise3_results.csv"
with open(csv_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["dataset", "loss", "degree_n", "max_error"])
    writer.writerows(results)
print(f"\nSaved results to {csv_path}")

# Plot error vs degree
import pandas as pd

df = pd.DataFrame(results, columns=["dataset", "loss", "degree_n", "max_error"])
for ds in DATASETS:
    sub = df[df["dataset"] == ds.name].copy()
    # Pivot to have columns per loss
    pivot = sub.pivot(index="degree_n", columns="loss", values="max_error").sort_index()

    plt.figure(figsize=(5, 4))
    if "huber" in pivot.columns:
        plt.plot(pivot.index.values, pivot["huber"].values, marker="o", label="Huber")
    if "lp" in pivot.columns:
        plt.plot(pivot.index.values, pivot["lp"].values, marker="s", label="L^1.5")

    plt.title(f"Max Error vs Degree — {ds.name}")
    plt.xlabel("Polynomial degree n")
    plt.ylabel("Max error on 1000 test points")
    plt.grid(True, alpha=0.4)
    plt.legend()
    out_png = f"exercise3_error_vs_degree_{ds.name.replace(' ', '_').replace('(', '').replace(')', '')}.png"
    plt.tight_layout()
    plt.savefig(out_png, dpi=300)
    plt.close()
    print(f"Saved plot: {out_png}")
# Out:
# sin(10x)                   | loss=huber | n= 1 | max_err=1.100200e+00
# sin(10x)                   | loss=huber | n= 2 | max_err=1.100200e+00
# sin(10x)                   | loss=huber | n= 3 | max_err=1.014121e+00
# sin(10x)                   | loss=huber | n= 4 | max_err=1.014121e+00
# sin(10x)                   | loss=huber | n= 5 | max_err=1.198895e+00
# sin(10x)                   | loss=huber | n= 6 | max_err=1.198895e+00
# sin(10x)                   | loss=huber | n= 7 | max_err=8.719792e-01
# sin(10x)                   | loss=huber | n= 8 | max_err=8.719854e-01
# sin(10x)                   | loss=huber | n= 9 | max_err=3.668513e-01
# sin(10x)                   | loss=huber | n=10 | max_err=3.668818e-01
# sin(10x)                   | loss=huber | n=11 | max_err=7.864535e-02
# sin(10x)                   | loss=huber | n=12 | max_err=7.867587e-02
# sin(10x)                   | loss=huber | n=13 | max_err=1.396027e-02
# sin(10x)                   | loss=huber | n=14 | max_err=1.416361e-02
# sin(10x)                   | loss=huber | n=15 | max_err=3.534281e-02
# sin(10x)                   | loss=huber | n=16 | max_err=3.515360e-02
# sin(10x)                   | loss=huber | n=17 | max_err=6.142008e-02
# sin(10x)                   | loss=huber | n=18 | max_err=6.114542e-02
# sin(10x)                   | loss=huber | n=19 | max_err=1.512408e-02
# sin(10x)                   | loss=huber | n=20 | max_err=1.494381e-02
# sin(10x)                   | loss=huber | n=21 | max_err=2.537799e-02
# sin(10x)                   | loss=huber | n=22 | max_err=2.550006e-02
# sin(10x)                   | loss=huber | n=23 | max_err=3.793940e-02
# sin(10x)                   | loss=huber | n=24 | max_err=3.821877e-02
# sin(10x)                   | loss=huber | n=25 | max_err=5.280146e-02
# sin(10x)                   | loss=huber | n=26 | max_err=5.261835e-02
# sin(10x)                   | loss=huber | n=27 | max_err=1.533860e-02
# sin(10x)                   | loss=huber | n=28 | max_err=1.485795e-02
# sin(10x)                   | loss=huber | n=29 | max_err=2.170914e-02
# sin(10x)                   | loss=huber | n=30 | max_err=2.177018e-02
# Runge function             | loss=huber | n= 1 | max_err=9.387383e-01
# Runge function             | loss=huber | n= 2 | max_err=8.684473e-01
# Runge function             | loss=huber | n= 3 | max_err=8.684473e-01
# Runge function             | loss=huber | n= 4 | max_err=8.026030e-01
# Runge function             | loss=huber | n= 5 | max_err=8.026029e-01
# Runge function             | loss=huber | n= 6 | max_err=7.415043e-01
# Runge function             | loss=huber | n= 7 | max_err=7.415047e-01
# Runge function             | loss=huber | n= 8 | max_err=6.849071e-01
# Runge function             | loss=huber | n= 9 | max_err=6.849076e-01
# Runge function             | loss=huber | n=10 | max_err=6.325086e-01
# Runge function             | loss=huber | n=11 | max_err=6.325001e-01
# Runge function             | loss=huber | n=12 | max_err=5.839814e-01
# Runge function             | loss=huber | n=13 | max_err=5.839407e-01
# Runge function             | loss=huber | n=14 | max_err=6.012566e-01
# Runge function             | loss=huber | n=15 | max_err=6.012765e-01
# Runge function             | loss=huber | n=16 | max_err=5.552545e-01
# Runge function             | loss=huber | n=17 | max_err=5.551745e-01
# Runge function             | loss=huber | n=18 | max_err=5.687850e-01
# Runge function             | loss=huber | n=19 | max_err=5.687878e-01
# Runge function             | loss=huber | n=20 | max_err=5.803488e-01
# Runge function             | loss=huber | n=21 | max_err=5.803593e-01
# Runge function             | loss=huber | n=22 | max_err=5.366300e-01
# Runge function             | loss=huber | n=23 | max_err=5.367038e-01
# Runge function             | loss=huber | n=24 | max_err=5.464429e-01
# Runge function             | loss=huber | n=25 | max_err=5.463817e-01
# Runge function             | loss=huber | n=26 | max_err=5.550351e-01
# Runge function             | loss=huber | n=27 | max_err=5.550294e-01
# Runge function             | loss=huber | n=28 | max_err=5.627946e-01
# Runge function             | loss=huber | n=29 | max_err=5.627949e-01
# Runge function             | loss=huber | n=30 | max_err=5.697526e-01
# Heaviside step function    | loss=huber | n= 1 | max_err=4.992567e-01
# Heaviside step function    | loss=huber | n= 2 | max_err=4.992568e-01
# Heaviside step function    | loss=huber | n= 3 | max_err=4.986058e-01
# Heaviside step function    | loss=huber | n= 4 | max_err=4.986060e-01
# Heaviside step function    | loss=huber | n= 5 | max_err=4.979664e-01
# Heaviside step function    | loss=huber | n= 6 | max_err=4.979661e-01
# Heaviside step function    | loss=huber | n= 7 | max_err=4.973289e-01
# Heaviside step function    | loss=huber | n= 8 | max_err=4.973287e-01
# Heaviside step function    | loss=huber | n= 9 | max_err=4.966920e-01
# Heaviside step function    | loss=huber | n=10 | max_err=4.966941e-01
# Heaviside step function    | loss=huber | n=11 | max_err=4.960535e-01
# Heaviside step function    | loss=huber | n=12 | max_err=4.960579e-01
# Heaviside step function    | loss=huber | n=13 | max_err=4.954153e-01
# Heaviside step function    | loss=huber | n=14 | max_err=4.954493e-01
# Heaviside step function    | loss=huber | n=15 | max_err=4.956665e-01
# Heaviside step function    | loss=huber | n=16 | max_err=4.956913e-01
# Heaviside step function    | loss=huber | n=17 | max_err=4.958466e-01
# Heaviside step function    | loss=huber | n=18 | max_err=4.958514e-01
# Heaviside step function    | loss=huber | n=19 | max_err=4.952756e-01
# Heaviside step function    | loss=huber | n=20 | max_err=4.952962e-01
# Heaviside step function    | loss=huber | n=21 | max_err=4.954026e-01
# Heaviside step function    | loss=huber | n=22 | max_err=4.953834e-01
# Heaviside step function    | loss=huber | n=23 | max_err=4.955286e-01
# Heaviside step function    | loss=huber | n=24 | max_err=4.955193e-01
# Heaviside step function    | loss=huber | n=25 | max_err=4.956595e-01
# Heaviside step function    | loss=huber | n=26 | max_err=4.956451e-01
# Heaviside step function    | loss=huber | n=27 | max_err=4.950471e-01
# Heaviside step function    | loss=huber | n=28 | max_err=4.951334e-01
# Heaviside step function    | loss=huber | n=29 | max_err=4.951590e-01
# Heaviside step function    | loss=huber | n=30 | max_err=4.951407e-01
# sin(10x)                   | loss=lp    | n= 1 | max_err=1.116296e+00
# sin(10x)                   | loss=lp    | n= 2 | max_err=1.116297e+00
# sin(10x)                   | loss=lp    | n= 3 | max_err=1.024522e+00
# sin(10x)                   | loss=lp    | n= 4 | max_err=1.024522e+00
# sin(10x)                   | loss=lp    | n= 5 | max_err=1.285684e+00
# sin(10x)                   | loss=lp    | n= 6 | max_err=1.285683e+00
# sin(10x)                   | loss=lp    | n= 7 | max_err=1.002980e+00
# sin(10x)                   | loss=lp    | n= 8 | max_err=1.002993e+00
# sin(10x)                   | loss=lp    | n= 9 | max_err=5.101466e-01
# sin(10x)                   | loss=lp    | n=10 | max_err=5.101924e-01
# sin(10x)                   | loss=lp    | n=11 | max_err=9.886217e-02
# sin(10x)                   | loss=lp    | n=12 | max_err=9.886217e-02
# sin(10x)                   | loss=lp    | n=13 | max_err=1.590285e-02
# sin(10x)                   | loss=lp    | n=14 | max_err=1.621857e-02
# sin(10x)                   | loss=lp    | n=15 | max_err=4.185334e-02
# sin(10x)                   | loss=lp    | n=16 | max_err=4.205543e-02
# sin(10x)                   | loss=lp    | n=17 | max_err=7.362711e-02
# sin(10x)                   | loss=lp    | n=18 | max_err=7.368815e-02
# sin(10x)                   | loss=lp    | n=19 | max_err=1.774859e-02
# sin(10x)                   | loss=lp    | n=20 | max_err=1.773676e-02
# sin(10x)                   | loss=lp    | n=21 | max_err=3.049311e-02
# sin(10x)                   | loss=lp    | n=22 | max_err=3.031000e-02
# sin(10x)                   | loss=lp    | n=23 | max_err=4.819331e-02
# sin(10x)                   | loss=lp    | n=24 | max_err=4.813629e-02
# sin(10x)                   | loss=lp    | n=25 | max_err=7.015070e-02
# sin(10x)                   | loss=lp    | n=26 | max_err=6.992182e-02
# sin(10x)                   | loss=lp    | n=27 | max_err=1.884049e-02
# sin(10x)                   | loss=lp    | n=28 | max_err=9.053835e-02
# sin(10x)                   | loss=lp    | n=29 | max_err=2.579850e-02
# sin(10x)                   | loss=lp    | n=30 | max_err=2.573746e-02
# Runge function             | loss=lp    | n= 1 | max_err=9.778009e-01
# Runge function             | loss=lp    | n= 2 | max_err=9.388131e-01
# Runge function             | loss=lp    | n= 3 | max_err=9.388131e-01
# Runge function             | loss=lp    | n= 4 | max_err=8.919439e-01
# Runge function             | loss=lp    | n= 5 | max_err=8.919440e-01
# Runge function             | loss=lp    | n= 6 | max_err=8.409146e-01
# Runge function             | loss=lp    | n= 7 | max_err=8.409148e-01
# Runge function             | loss=lp    | n= 8 | max_err=7.914386e-01
# Runge function             | loss=lp    | n= 9 | max_err=7.914383e-01
# Runge function             | loss=lp    | n=10 | max_err=7.379546e-01
# Runge function             | loss=lp    | n=11 | max_err=7.379549e-01
# Runge function             | loss=lp    | n=12 | max_err=6.937609e-01
# Runge function             | loss=lp    | n=13 | max_err=6.938075e-01
# Runge function             | loss=lp    | n=14 | max_err=7.128322e-01
# Runge function             | loss=lp    | n=15 | max_err=7.128282e-01
# Runge function             | loss=lp    | n=16 | max_err=6.591725e-01
# Runge function             | loss=lp    | n=17 | max_err=6.592361e-01
# Runge function             | loss=lp    | n=18 | max_err=6.752168e-01
# Runge function             | loss=lp    | n=19 | max_err=6.752694e-01
# Runge function             | loss=lp    | n=20 | max_err=6.890489e-01
# Runge function             | loss=lp    | n=21 | max_err=6.890884e-01
# Runge function             | loss=lp    | n=22 | max_err=6.353856e-01
# Runge function             | loss=lp    | n=23 | max_err=6.352323e-01
# Runge function             | loss=lp    | n=24 | max_err=6.475052e-01
# Runge function             | loss=lp    | n=25 | max_err=6.473922e-01
# Runge function             | loss=lp    | n=26 | max_err=6.585991e-01
# Runge function             | loss=lp    | n=27 | max_err=6.586056e-01
# Runge function             | loss=lp    | n=28 | max_err=6.676923e-01
# Runge function             | loss=lp    | n=29 | max_err=6.676499e-01
# Runge function             | loss=lp    | n=30 | max_err=6.758547e-01
# Heaviside step function    | loss=lp    | n= 1 | max_err=4.992762e-01
# Heaviside step function    | loss=lp    | n= 2 | max_err=4.992762e-01
# Heaviside step function    | loss=lp    | n= 3 | max_err=4.986948e-01
# Heaviside step function    | loss=lp    | n= 4 | max_err=4.986948e-01
# Heaviside step function    | loss=lp    | n= 5 | max_err=4.981350e-01
# Heaviside step function    | loss=lp    | n= 6 | max_err=4.981345e-01
# Heaviside step function    | loss=lp    | n= 7 | max_err=4.975751e-01
# Heaviside step function    | loss=lp    | n= 8 | max_err=4.975755e-01
# Heaviside step function    | loss=lp    | n= 9 | max_err=4.970301e-01
# Heaviside step function    | loss=lp    | n=10 | max_err=4.970379e-01
# Heaviside step function    | loss=lp    | n=11 | max_err=4.964749e-01
# Heaviside step function    | loss=lp    | n=12 | max_err=4.964870e-01
# Heaviside step function    | loss=lp    | n=13 | max_err=4.959469e-01
# Heaviside step function    | loss=lp    | n=14 | max_err=4.959130e-01
# Heaviside step function    | loss=lp    | n=15 | max_err=4.961369e-01
# Heaviside step function    | loss=lp    | n=16 | max_err=4.961478e-01
# Heaviside step function    | loss=lp    | n=17 | max_err=4.963164e-01
# Heaviside step function    | loss=lp    | n=18 | max_err=4.963038e-01
# Heaviside step function    | loss=lp    | n=19 | max_err=4.957889e-01
# Heaviside step function    | loss=lp    | n=20 | max_err=4.957759e-01
# Heaviside step function    | loss=lp    | n=21 | max_err=4.959261e-01
# Heaviside step function    | loss=lp    | n=22 | max_err=4.959553e-01
# Heaviside step function    | loss=lp    | n=23 | max_err=4.960208e-01
# Heaviside step function    | loss=lp    | n=24 | max_err=4.960018e-01
# Heaviside step function    | loss=lp    | n=25 | max_err=4.961338e-01
# Heaviside step function    | loss=lp    | n=26 | max_err=4.961263e-01
# Heaviside step function    | loss=lp    | n=27 | max_err=4.962197e-01
# Heaviside step function    | loss=lp    | n=28 | max_err=4.962284e-01
# Heaviside step function    | loss=lp    | n=29 | max_err=4.957655e-01
# Heaviside step function    | loss=lp    | n=30 | max_err=4.957519e-01
#
# Saved results to exercise3_results.csv
# Saved plot: exercise3_error_vs_degree_sin10x.png
# Saved plot: exercise3_error_vs_degree_Runge_function.png
# Saved plot: exercise3_error_vs_degree_Heaviside_step_function.png
